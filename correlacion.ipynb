# %% [markdown]
# <a href="https://colab.research.google.com/github/Pemoreira74/Trabajo-EPH/blob/main/correlacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install researchpy

# %%
import pandas as pd
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import researchpy as rp
import seaborn as sns
import matplotlib.pyplot as plt


# Especifica la ruta del archivo CSV
ruta_archivo_csv = '/content/drive/MyDrive/EPH/IFP_correlacion.csv'

# Crea un DataFrame desde el archivo CSV
df = pd.read_csv(ruta_archivo_csv)

# Muestra las ultimas filas del DataFrame para verificar
print(df.tail(5))
# Out:
#          ANO4  TRIMESTRE      region  AGLOMERADO  sexo  edad  analfabetismo  \
# 3984640  2022          4  Patagónica          93     2    83              1
# 3984641  2022          4  Patagónica          93     2    83              1
# 3984642  2022          4  Patagónica          93     2    84              2
# 3984643  2022          4  Patagónica          93     2    86              1
# 3984644  2022          4  Patagónica          93     2    92              1
#
#          nivel_educativo  tipo_vivienda  zona_inundable  villa_emergencia  \
# 3984640                6              1               2                 2
# 3984641                6              1               2                 2
# 3984642                7              1               2                 2
# 3984643                2              1               2                 2
# 3984644                2              1               2                 2
#
#          cant_miembros_hogar  promedio_ifpc  ESTADO
# ...

# %%
#Seleccionamos las columnas relevantes para el análisis
columnas_interes = ['region','sexo', 'edad', 'analfabetismo', 'nivel_educativo', 'tipo_vivienda', 'zona_inundable',
                    'villa_emergencia', 'cant_miembros_hogar', 'promedio_ifpc']

# Filtra el DataFrame para incluir solo las columnas de interés
df_interes = df[columnas_interes]

# Calcula la matriz de correlación
matriz_correlacion = df_interes.corr()

# Imprime la matriz de correlación
print("Matriz de correlación:")
print(matriz_correlacion)
# Out:
# <ipython-input-5-73777505bc2e>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = df_interes.corr()
# Matriz de correlación:
#                          sexo      edad  analfabetismo  nivel_educativo  \
# sexo                 1.000000  0.057826      -0.016235         0.037141
# edad                 0.057826  1.000000      -0.359105        -0.146595
# analfabetismo       -0.016235 -0.359105       1.000000         0.425625
# nivel_educativo      0.037141 -0.146595       0.425625         1.000000
# tipo_vivienda        0.004646 -0.048583       0.023882         0.064293
# zona_inundable       0.002988  0.076425      -0.042706         0.041565
# villa_emergencia     0.006008  0.069268      -0.044982         0.039533
# cant_miembros_hogar -0.019915 -0.318841       0.111454        -0.103692
# ...

# %%
# También puedes imprimir un mapa de calor para visualizar la correlación
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Mapa de calor de correlación entre variables')
plt.show()
